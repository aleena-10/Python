# %%
from tkinter import *
from tkinter import ttk
from tkinter import messagebox
#import pymysql
import sqlite3#sqlite
win=Tk()
win.geometry("800x800")
win.title("MUSIC SCHOOL")
win.configure(bg="pink")

def insert():
    #con=pymysql.connect("localhost","root","","schldb")
    con=sqlite3.connect("database.db")
    cur=con.cursor()
    sid=int(eid.get())
    fname=efn.get()
    lname=eln.get()
    gn=var.get()
    ch=dropvar.get()
    day=var1.get()+var2.get()+var3.get()+var4.get()+var5.get()+var6.get()+var7.get()
    length=len(eph.get())
    ph=int(eph.get())
    if length==10:
        sql="insert into student(id,fname,lname,gen,course,class,mobile)values('%d','%s','%s','%s','%s','%s','%d')"%(sid,fname,lname,gn,ch,day,ph)
        cur.execute(sql)
        con.commit()
        messagebox.showinfo("Registration","Sucessfully Registered!!")
        eid.delete(0,END)
        efn.delete(0,END)
        eln.delete(0,END)
        eph.delete(0,END)
        ccb.current(0)
        cb1.deselect()
        cb2.deselect()
        cb3.deselect()
        cb4.deselect()
        cb5.deselect()
        cb6.deselect()
        cb7.deselect()
        
    else:
        messagebox.showinfo("Registration","Mobile number must have 10 digits!!")
#new window

#view all
def view():
    conn=sqlite3.connect("database.db")
    cur=conn.cursor()
    sql="select * from student"    
    cur.execute(sql)
    result=cur.fetchall()
    if result!=[]:
        win1=Toplevel(win)
        win1.geometry("800x800")
        win1.title("Operations")
        win1.configure(bg="pink")
        #conn=pymysql.connect("localhost","root","","schldb")
        print(result)
        i=0
        l1=Label(win1,text="Student id",bg="pink",font=("arial",10,"bold"))
        l2=Label(win1,text="Name",bg="pink",font=("arial",10,"bold"))
        #l2=Label(win1,text="Last Name",bg="pink",font=("arial",10,"bold"))
        l3=Label(win1,text="Gender",bg="pink",font=("arial",10,"bold"))
        l4=Label(win1,text="Course",bg="pink",font=("arial",10,"bold"))
        l5=Label(win1,text="Days",bg="pink",font=("arial",10,"bold"))
        l6=Label(win1,text="Mobile number",bg="pink",font=("arial",10,"bold"))
        l1.grid(row=0,column=1)
        l2.grid(row=0,column=2)
        l3.grid(row=0,column=4)
        l4.grid(row=0,column=5)
        l5.grid(row=0,column=6)
        l6.grid(row=0,column=7)
        for r in result :
            for j in range(len(r)):
               l=Label(win1,text=r[j],bg="pink",font=("arial",10,""))
               l.grid(row=i+1,column=j+1)
            i=i+1
        
    else:
        messagebox.showinfo("VIEW","Table is empty!!")
    conn.commit()
def search():
    id1=le.get()
    
    #conn=pymysql.connect("localhost","root","","schldb")
    conn=sqlite3.connect("database.db")
    cur=conn.cursor()
    sql="select * from student where id='"+id1+"'"
    cur.execute(sql)
    result=cur.fetchall()
    if result!=[]:
        win1=Toplevel(win)
        win1.geometry("800x800")
        win1.title("Operations")
        win1.configure(bg="pink")
        i=0
        l1=Label(win1,text="Student id",bg="pink",font=("arial",10,"bold"))
        l2=Label(win1,text="Name",bg="pink",font=("arial",10,"bold"))
        #l2=Label(win1,text="Last Name",bg="pink",font=("arial",10,"bold"))
        l3=Label(win1,text="Gender",bg="pink",font=("arial",10,"bold"))
        l4=Label(win1,text="Course",bg="pink",font=("arial",10,"bold"))
        l5=Label(win1,text="Days",bg="pink",font=("arial",10,"bold"))
        l6=Label(win1,text="Mobile number",bg="pink",font=("arial",10,"bold"))
        l1.grid(row=0,column=1)
        l2.grid(row=0,column=2)
        l3.grid(row=0,column=4)
        l4.grid(row=0,column=5)
        l5.grid(row=0,column=6)
        l6.grid(row=0,column=7)
        for r in result :
            for j in range(len(r)):
               l=Label(win1,text=r[j],bg="pink",font=("arial",10,""))
               l.grid(row=i+1,column=j+1)
            i=i+1
        
    else:
        messagebox.showinfo("VIEW","Not such student exist!!")
    conn.commit()
def update():
   
    #conn=pymysql.connect("localhost","root","","schldb")
    conn=sqlite3.connect("database.db")
    cur=conn.cursor()
    sid=int(eid.get())
    fname=efn.get()
    lname=eln.get()
    gn=var.get()
    ch=dropvar.get()
    day=var1.get()+var2.get()+var3.get()+var4.get()+var5.get()+var6.get()+var7.get()
    length=len(eph.get())
    ph=int(eph.get())
    sql1="select * from student where id='"+str(sid)+"'"
    cur.execute(sql1)
    if cur.rowcount!=0:
        if length==10:
            sql="update student set fname='%s',lname='%s',gen='%s',course='%s',class='%s',mobile='%d' where id='%d'"%(fname,lname,gn,ch,day,ph,sid)
            cur.execute(sql)
            conn.commit()
            messagebox.showinfo("Registration","Sucessfully Updated!!")
            eid.delete(0,END)
            efn.delete(0,END)
            eln.delete(0,END)
            eph.delete(0,END)
            ccb.current(0)
            cb1.deselect()
            cb2.deselect()
            cb3.deselect()
            cb4.deselect()
            cb5.deselect()
            cb6.deselect()
            cb7.deselect()
        else:
            messagebox.showinfo("Registration","Mobile number must have 10 digits!!")
    else:
        messagebox.showinfo("VIEW","Not such student exist!!")
    conn.commit()
def delete(id3):
    #conn=pymysql.connect("localhost","root","","schldb")
    conn=sqlite3.connect("database.db")
    cur=conn.cursor()
   
    sql1="select * from student where id='"+str(id3)+"'"
    cur.execute(sql1)
    if cur.rowcount!=0:
        sql="delete from student where id='"+str(id3)+"'"
        cur.execute(sql)
        conn.commit()
        messagebox.showinfo("Registration","Sucessfully Deleted!!")
    else:
        messagebox.showinfo("VIEW","Not such student exist!!")
    
    
l1=Label(text="Registration",bg="pink",font=("arial",20,"bold"))
l1.place(x=240,y=10)
#id
lid=Label(text="Student ID",bg="pink",font=("arial",12,""))
lid.place(x=10,y=70)
eid=Entry(win,width="50",)
eid.place(x=230,y=70)
#fname
lfn=Label(text="First Name",bg="pink",font=("arial",12,""))
lfn.place(x=10,y=120)
efn=Entry(win,width="50")
efn.place(x=230,y=120)
#lname
lln=Label(text="Last Name",bg="pink",font=("arial",12,""))
lln.place(x=10,y=170)
eln=Entry(win,width="50")
eln.place(x=230,y=170)
#gender
lg=Label(text="Gender",bg="pink",font=("arial",12,""))
lg.place(x=10,y=220)
var=StringVar()
rg=Radiobutton(win,text="Male",variable=var,value="male",bg="pink")
rg.place(x=230,y=220)
rg.select()

rg1=Radiobutton(win,text="Female",variable=var,value="female",bg="pink")
rg1.place(x=300,y=220)
#choice
lc=Label(text="Choice course",bg="pink",font=("arial",12,""))
lc.place(x=10,y=270)
dropvar=StringVar()
list1=["--select--","Dance","Music","flute","Piano"]
ccb=ttk.Combobox(values=list1,textvariable=dropvar,width="50")
ccb.current(0)
ccb.place(x=230,y=270)
#day
lcls=Label(text="Day for class",bg="pink",font=("arial",12,""))
lcls.place(x=10,y=320)
var1=StringVar()
var2=StringVar()
var3=StringVar()
var4=StringVar()
var5=StringVar()
var6=StringVar()
var7=StringVar()
cb1=Checkbutton(text="Sun",variable=var1,onvalue="Sun,",offvalue="",bg="pink")
cb1.place(x=230,y=320)
cb2=Checkbutton(text="Mon",variable=var2,onvalue="Mon,",offvalue="",bg="pink")
cb2.place(x=280,y=320)
cb3=Checkbutton(text="Tue",variable=var3,onvalue="Tue,",offvalue="",bg="pink")
cb3.place(x=330,y=320)
cb4=Checkbutton(text="Wed",variable=var4,onvalue="Wed,",offvalue="",bg="pink")
cb4.place(x=380,y=320)
cb5=Checkbutton(text="Thur",variable=var5,onvalue="Thu,",offvalue="",bg="pink")
cb5.place(x=430,y=320)
cb6=Checkbutton(text="Fri",variable=var6,onvalue="Fri,",offvalue="",bg="pink")
cb6.place(x=480,y=320)
cb7=Checkbutton(text="Sat",variable=var7,onvalue="Sat",offvalue="",bg="pink")
cb7.place(x=530,y=320)
#phone number
lph=Label(text="Mobile Number",bg="pink",font=("arial",12,""))
lph.place(x=10,y=370)
eph=Entry(width="50")
eph.place(x=230,y=370)
btn=Button(text="Submit",command=insert)
btn.place(x=300,y=420)
v=Button(text="ViewAll1",command=view)
v.place(x=360,y=420)
ll=Label(text="Search By ID",bg="pink")
ll.place(x=150,y=470)
le=Entry(width="20")
le.place(x=270,y=470)



sbtn=Button(win,text="Search",command=search)
sbtn.place(x=400,y=470)
ubtn=Button(win,text="Update",command=update)
ubtn.place(x=430,y=420)

l3=Label(text="delete By ID",bg="pink")
l3.place(x=470,y=470)
de=Entry(width="20")
de.place(x=550,y=470)

dbtn=Button(win,text="Delete",command=lambda:delete(de.get()))
dbtn.place(x=680,y=470)


win.mainloop()
